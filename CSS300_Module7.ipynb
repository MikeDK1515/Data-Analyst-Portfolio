# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
wines = pd.read_csv("wines_cleaned.csv")
wines = wines.drop(wines.index[wines['density'] > 1.02], inplace = False)
wines = wines.drop(wines.index[wines['free sulfur dioxide'] > 200], inplace = False)

# %%
plt.figure(figsize=(10,10))

sns.heatmap(wines.corr(), vmin=-1, vmax=1, annot=True, annot_kws={"fontsize":14}, cmap="RdBu_r")
# Out:
# <AxesSubplot:>

# %%
wines.plot(x='free sulfur dioxide', y='total sulfur dioxide', style='o')
plt.title('Free vs Total Sulfur Dioxide') 
plt.xlabel('Free Sulfur Dioxide') 
plt.ylabel('Total Sulfur Dioxide ') 
plt.show()

# %%
wines.plot(x='density', y='alcohol', style='o') 
plt.title('Density vs Alcohol') 
plt.xlabel('Density') 
plt.ylabel('Alcohol') 
plt.show()

# %%
x = wines['density'].values.reshape(-1,1)
y = wines['alcohol'].values.reshape(-1,1)

# %%
wines['density']
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 4       0.99780
#          ...
# 4376    0.99114
# 4377    0.99490
# 4378    0.99254
# 4379    0.98869
# 4380    0.98941
# Name: density, Length: 4379, dtype: float64

# %%
x
# Out:
# array([[0.9978 ],
#        [0.9968 ],
#        [0.997  ],
#        ...,
#        [0.99254],
#        [0.98869],
#        [0.98941]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train
# Out:
# array([[0.99581],
#        [0.9956 ],
#        [0.9983 ],
#        ...,
#        [0.9937 ],
#        [0.994  ],
#        [0.99378]])

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept: ", regressor.intercept_)
print("Slope (beta coefficient): ", regressor.coef_)
# Out:
# Intercept:  [287.61452181]
# Slope (beta coefficient):  [[-278.58003199]]
